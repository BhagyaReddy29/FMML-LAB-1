# %% [markdown]
# <a href="https://colab.research.google.com/github/BhagyaReddy29/FMML-LABS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 14:48:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   105MB/s    in 0.7s
#
# 2024-03-28 14:48:29 (105 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29326  1709.01182v1  Research on human face processing using eye mo...    cs
# 35851   1301.6479v2  Ontology-based data access is concerned with q...    cs
# 22339  1602.05822v1  Sampling with replacement occurs in many setti...  stat
# 7461   1801.01799v1  We present novel understandings of the Gamma-P...  stat
# 11153   1410.6853v2  Mean Field Variational Bayes (MFVB) is a popul...  stat
# ...             ...                                                ...   ...
# 7112   1710.05654v1  Graphs are a prevalent tool in data science, a...  stat
# 22027   1312.2967v3  This paper aims at justifying LWF and AMP chai...  stat
# 37635  1711.06930v1  We provide, to the best of our knowledge, the ...    cs
# 22164  1506.03768v1  Learning of low dimensional structure in multi...  stat
# 7678   1802.07714v1  The roles played by learning and memorization ...  stat
#
#                                                    title  year  \
# 29326  Is human face processing a feature- or pattern...  2017
# 35851  Ontology-based Data Access: A Study through Di...  2013
# 22339  What is the distribution of the number of uniq...  2016
# 7461   Closed-form marginal likelihood in Gamma-Poiss...  2018
# 11153  Covariance Matrices for Mean Field Variational...  2014
# ...                                                  ...   ...
# 7112      Large Scale Graph Learning from Smooth Signals  2017
# 22027  Every LWF and AMP chain graph originates from ...  2013
# 37635  Computational Results for Extensive-Form Adver...  2017
# 22164  Probabilistic Curve Learning: Coulomb Repulsio...  2015
# 7678   Detecting Learning vs Memorization in Deep Neu...  2018
#
#                                                 keywords
# 29326  [processing, movements, recognize, successfull...
# 35851  [concerned, incomplete, knowledge, conjunctive...
# 22339  [replacement, technique, validation, bootstrap...
# 7461   [understandings, probabilistic, factorization,...
# 11153  [variational, posterior, approximation, undere...
# ...                                                  ...
# 7112   [prevalent, structure, successfully, unsupervi...
# 22027  [justifying, represent, arbitrary, independenc...
# 37635  [knowledge, computational, extensive, adversar...
# 22164  [dimensional, structure, multidimensional, can...
# 7678   [memorization, represent, important, optimizat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29326    [processing, movements, recognize, successfull...
# 35851    [concerned, incomplete, knowledge, conjunctive...
# 22339    [replacement, technique, validation, bootstrap...
# 7461     [understandings, probabilistic, factorization,...
# 11153    [variational, posterior, approximation, undere...
#                                ...
# 22033    [bipartite, perspective, functional, independe...
# 21564    [algorithm, expectation, propagation, relaxati...
# 5140     [conformal, prediction, experience, determine,...
# 37913    [orthogonal, expansion, parameters, expansions...
# 14103    [algorithm, porcellio, algorithm, constrained,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8747 words.
# Out of those 4612 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be11a170-43d5-4866-ae42-c95bb26a1fa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be11a170-43d5-4866-ae42-c95bb26a1fa7")) {                    Plotly.newPlot(                        "be11a170-43d5-4866-ae42-c95bb26a1fa7",                        [{"x":["recognition","recognizing","understand","implements","computational","attention","participants","information","indicated","experimental","databases","recognize","representation","movements","accomplish","available","multivariate","fixations","statistics","extraction","efficiently","successfully","dimensional","expression","processing","multidimensional","establish","connections","formulated","fragments","generalization","description","satisfaction","characterize","concerned","conjunctive","disjunctive","knowledge","rewritability","contributions","incomplete","expressive","regarding","containment","ontologies","constraint","techniques","heuristic","validation","technique","important","distribution","bootstrap","categories","concisely","empirical","prediction","characteristics","classification","generalisation","resampling","replacement","researchers","duplicate","behaviour","investigation","approximation","permissible","estimator","properties","favorable","probabilistic","dictionary","robustness","activation","expectation","understandings","rewritten","factorization","marginalization","automatically","specified","maximization","likelihood","particular","estimation","algorithm","empirically","uncertainty","approximating","demonstrate","exponential","underestimates","methodology","individual","estimates","coherently","variational","perturbing","posterior","variables","simulated","covariance","efficient","different","investigate","importance","generally","guaranteed","sacrificing","classifiers","classifier","optimality","exploited","numerical","intensive","approaches","experiments","beforehand","substantially","difficult","practical","introduce","influence","characterized","screening","advantage","contributes","directions","physiology","augmentation","comparison","hypothetical","considered","landscape","behavioral","presented","alternate","processes","community","adaptability","interface","discussed","physiological","relevance","preferable","introduced","performance","optimizes","separately","partially","computing","achieving","essentially","stochastic","specifically","literature","adversarial","algorithms","instances","processed","illustrate","classified","explaining","implemented","explained","considering","differently","closeness","principle","identifying","definition","interpretability","addresses","observation","generation","neighbour","integrates","determining","represent","observations","specificity","assignments","associated","drawbacks","illustrations","therefore","interests","contradiction","interpret","functions","dimension","neuroscience","perspective","cognitive","solutions","reduction","challenge","reference","representations"],"y":[387,35,60,13,297,174,21,692,3,365,54,41,410,10,14,310,19,3,59,138,155,86,154,56,300,15,50,51,46,19,108,81,23,58,24,9,7,361,2,45,30,31,36,2,25,96,384,54,61,259,302,205,6,60,0,146,229,83,480,8,0,9,56,0,34,36,120,2,24,229,11,180,66,97,39,24,1,1,49,6,195,32,25,64,283,229,810,54,85,13,549,50,0,85,106,67,1,48,0,36,120,68,23,404,750,160,86,73,22,9,112,164,20,31,109,21,398,629,0,42,145,136,318,52,32,9,94,12,49,2,33,126,4,138,10,19,170,7,103,64,5,28,56,4,37,8,117,898,8,34,52,132,90,20,116,190,126,94,567,109,39,78,32,18,108,26,81,19,3,42,80,36,28,57,64,136,3,31,31,123,68,12,15,119,16,3,122,20,3,30,209,59,5,68,38,135,102,153,60,239],"type":"bar"},{"x":["recognition","recognizing","understand","implements","computational","attention","parti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4612,), (4612, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Joint</span> <span style=''>Matrix</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.32876712328767127);'>Factorization</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384615);'>Knowledge</span> <span style=''>Base</span> <span style='background-color:rgba(255, 0, 0, 0.33901192504258953);'>Inference</span> <br/><br/><span style=''>While</span> <span style=''>several</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.32876712328767127);'>factorization</span> <span style=''>(MF)</span> <span style=''>and</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.32876712328767127);'>factorization</span> <span style=''>(TF)</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384615);'>knowledge</span> <span style=''>base</span> <span style=''>(KB)</span> <span style='background-color:rgba(255, 0, 0, 0.33901192504258953);'>inference</span> <span style=''>they</span> <span style=''>have</span> <span style=''>rarely</span> <span style=''>been</span> <span style=''>compared</span> <span style=''>across</span> <span style=''>various</span> <span style=''>datasets</span> <span style=''>Is</span> <span style=''>there</span> <span style=''>a</span> <span style=''>single</span> <span style=''>model</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>well</span> <span style=''>across</span> <span style=''>datasets</span> <span style=''>If</span> <span style=''>not</span> <span style=''>what</span> <span style='background-color:rgba(0, 255, 0, 0.34959349593495936);'>characteristics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>MF</span> <span style=''>and</span> <span style=''>TF</span> <span style=''>models</span> <span style=''>Is</span> <span style=''>there</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>TFMF</span> <span style=''>model</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>robustly</span> <span style=''>on</span> <span style=''>all</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>perform</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.423728813559322);'>evaluation</span> <span style=''>to</span> <span style=''>compare</span> <span style=''>popular</span> <span style=''>KB</span> <span style='background-color:rgba(255, 0, 0, 0.33901192504258953);'>inference</span> <span style=''>models</span> <span style=''>across</span> <span style=''>popular</span> <span style=''>datasets</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.7428571428571429);'>answering</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4845360824742267);'>questions</span> <span style=''>above</span> <span style=''>we</span> <span style=''>remove</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4499999999999998);'>limitation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.423728813559322);'>evaluation</span> <span style=''>protocol</span> <span style=''>for</span> <span style=''>MF</span> <span style=''>models</span> <span style=''>propose</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>a</span> <span style=''>Class</span> <span style=''>of</span> <span style=''>Bias</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Amplifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <span style=''>that</span> <span style=''>Endanger</span> <span style=''>Effect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimates</span> <br/><br/><span style=''>This</span> <span style=''>note</span> <span style=''>deals</span> <span style=''>with</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>that</span> <span style=''>if</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>amplify</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style=''>bias</span> <span style=''>in</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>causal</span> <span style=''>effects</span> <span style=''>This</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovered</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bhattacharya</span> <span style=''>and</span> <span style=''>Vogt</span> <span style=''>(2007)</span> <span style=''>and</span> <span style=''>Wooldridge</span> <span style=''>(2009)</span> <span style=''>includes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instrumental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>that</span> <span style=''>have</span> <span style=''>greater</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>than</span> <span style=''>on</span> <span style=''>the</span> <span style=''>outcome</span> <span style=''>We</span> <span style=''>offer</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivation</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomenon</span> <span style=''>and</span> <span style=''>then</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>to</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>1</span> <span style=''>the</span> <span style=''>bias</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>amplifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instrumental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>extends</span> <span style=''>over</span> <span style=''>to</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>though</span> <span style=''>not</span> <span style=''>as</span> <span style=''>sweepingly</span> <span style=''>as</span> <span style=''>in</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>2</span> <span style=''>in</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preconditioning</span> <span style=''>approach</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preconditioning</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>the</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>metric</span> <span style=''>or</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>exploits</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>and</span> <span style=''>takes</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>symmetry</span> <span style=''>that</span> <span style=''>exists</span> <span style=''>in</span> <span style=''>Tucker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>The</span> <span style=''>specific</span> <span style=''>metric</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>versatile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>on</span> <span style=''>quotient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preconditioned</span> <span style='background-color:rgba(255, 0, 0, 0.4337349397590362);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.6129032258064517);'>conjugate</span> <span style=''>gradient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.4035989717223652);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>batch</span> <span style=''>and</span> <span style=''>online</span> <span style=''>setups</span> <span style='background-color:rgba(0, 255, 0, 0.4090909090909091);'>respectively</span> <span style=''>Concrete</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.42261904761904756);'>representations</span> <span style=''>of</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>ingredients</span> <span style=''>are</span> <span style=''>listed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Numerical</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Reconstruction</span> <span style=''>from</span> <span style=''>Periodic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinearities</span> <span style=''>With</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style=''>HDR</span> <span style=''>Imaging</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructing</span> <span style=''>signals</span> <span style=''>and</span> <span style=''>images</span> <span style=''>from</span> <span style=''>periodic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinearities</span> <span style=''>For</span> <span style=''>such</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>design</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>supports</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>moreover</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressive</span> <span style=''>sensing</span> <span style=''>based</span> <span style=''>signal</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>systems</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>high</span> <span style=''>dynamic</span> <span style=''>range</span> <span style=''>(HDR)</span> <span style=''>imaging</span> <span style=''>systems</span> <span style=''>with</span> <span style=''>little</span> <span style=''>loss</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>quality</span> <span style=''>Several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>real</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13091822094691535)
# 	processing (0.10760401721664276)
# 	segmentation (0.07173601147776183)
# 	detection (0.11370157819225252)
# 	knowledge (0.12948350071736012)
# 	information (0.24820659971305595)
# 	representation (0.14705882352941177)
# 	recognition (0.13880918220946914)
# 	different (0.26901004304160686)
# 	convolutional (0.14311334289813488)
#
# Some Statistics words are:
# 	algorithms (0.28727634194831014)
# 	variables (0.1327037773359841)
# 	theoretical (0.15357852882703776)
# 	stochastic (0.13568588469184892)
# 	distribution (0.16848906560636182)
# 	statistical (0.15705765407554673)
# 	algorithm (0.40407554671968193)
# 	inference (0.19532803180914513)
# 	dimensional (0.18836978131212723)
# 	regression (0.17992047713717693)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0cd46794-b6b8-4d16-9c38-d5fa52c3870b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cd46794-b6b8-4d16-9c38-d5fa52c3870b")) {                    Plotly.newPlot(                        "0cd46794-b6b8-4d16-9c38-d5fa52c3870b",                        [{"x":["recognition","recognizing","understand","implements","computational","attention","participants","information","indicated","experimental","databases","recognize","representation","movements","accomplish","available","multivariate","fixations","statistics","extraction","efficiently","successfully","dimensional","expression","processing","multidimensional","establish","connections","formulated","fragments","generalization","description","satisfaction","characterize","concerned","conjunctive","disjunctive","knowledge","rewritability","contributions","incomplete","expressive","regarding","containment","ontologies","constraint","techniques","heuristic","validation","technique","important","distribution","bootstrap","categories","concisely","empirical","prediction","characteristics","classification","generalisation","resampling","replacement","researchers","duplicate","behaviour","investigation","approximation","permissible","estimator","properties","favorable","probabilistic","dictionary","robustness","activation","expectation","understandings","rewritten","factorization","marginalization","automatically","specified","maximization","likelihood","particular","estimation","algorithm","empirically","uncertainty","approximating","demonstrate","exponential","underestimates","methodology","individual","estimates","coherently","variational","perturbing","posterior","variables","simulated","covariance","efficient","different","investigate","importance","generally","guaranteed","sacrificing","classifiers","classifier","optimality","exploited","numerical","intensive","approaches","experiments","beforehand","substantially","difficult","practical","introduce","influence","characterized","screening","advantage","contributes","directions","physiology","augmentation","comparison","hypothetical","considered","landscape","behavioral","presented","alternate","processes","community","adaptability","interface","discussed","physiological","relevance","preferable","introduced","performance","optimizes","separately","partially","computing","achieving","essentially","stochastic","specifically","literature","adversarial","algorithms","instances","processed","illustrate","classified","explaining","implemented","explained","considering","differently","closeness","principle","identifying","definition","interpretability","addresses","observation","generation","neighbour","integrates","determining","represent","observations","specificity","assignments","associated","drawbacks","illustrations","therefore","interests","contradiction","interpret","functions","dimension","neuroscience","perspective","cognitive","solutions","reduction","challenge","reference","representations","extensive","substantial","aggregate","statistical","heterogeneous","conditions","automated","universal","cognition","psychological","constrained","hierarchical","application","framework","guarantee","reinforcement","execution","behaviors","environment","interactions","perceptions","discarded","convergence","capabilities","desirable","otherwise","quantities","including","identifiable","naturally","unmeasured","confounding","conditional","inference","evaluation","distributions","independencies","informative","manipulators","convolutional","resulting","assistive","environments","communities","subsequently","detection","proposals","localization","observational","generates","generator","distinguish","interventions","structural","penalized ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	concisely
# 	resampling
# 	duplicate
# 	underestimates
# 	perturbing
# 	beforehand
# 	unmeasured
# 	missforest
# 	regularizations
# 	marginalisation
# 	traversing
# 	metastable
# 	submodularity
# 	beautiful
# 	encapsulated
# 	representer
# 	thermodynamics
# 	multimodality
# 	autoencoding
# 	collapsing
# Some words which never appear in Statistics papers:
# 	fixations
# 	disjunctive
# 	rewritability
# 	physiology
# 	contradiction
# 	perceptions
# 	discarded
# 	manipulators
# 	assistive
# 	worldwide
# 	performer
# 	middlebury
# 	emphasizes
# 	orderings
# 	justifications
# 	prefrontal
# 	extendable
# 	professionals
# 	spacecraft
# 	preconditions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077680659854734e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
